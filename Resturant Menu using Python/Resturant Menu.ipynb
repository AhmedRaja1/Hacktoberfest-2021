# %%
try:
    menu = int(input(' [1] BURGERS [2] STEAKS [3] EXIT \n \n  SELECT ITEMS : '))
except ValueError:
    print("PLEASE ENTER INTEGER \n \n")
burgers = [['Zinger Burger : 230/-'],['Zinger Cheese Burger : 260/-'],['Thames Special Burger : 320/-'],['Beef Burger : 250/-'],['Tower Burger : 320/-'],['Fish Burger : 260'],['Fish Cheese Burger : 290/-'],['Fire Stone Burger : 170/-'],['Crispy Burger : 170/-'],['Chicken Burger : 180/-'],['Tikka Burger : 170/-'],['Shami Burger : 170/-']]
steaks = [['Arizona Steak : 650/-'],['Mushroom Steak : 650/-'],['Pepper Steak : 650/-'],['Polo Tuscany : 650/-']]

if menu == 1:
    for i in burgers:
        print(i)
        
    
    select = int(input("SELECT BURGERS :"))
    
    if select == 1:
        print(burgers[1])
    elif select == 2:
        print(burgers[2])
    elif select == 3:
        print(burgers[3])
    elif select == 4:
        print(burgers[4])
    elif select == 5:
        print(burgers[5])
    elif select == 6:
        print(burgers[6])
    elif select == 7:
        print(burgers[7])
    elif select == 8:
        print(burgers[8])
    elif select == 9:
        print(burgers[9])
    elif select == 10:
        print(burgers[10])
    elif select == 11:
        print(burgers[11])
    elif select == 12:
        print(burgers[12])
    else: 
        print("PLEASE SELECT BURGERS WHICH ARE GIVEN IN LIST")
        
        
    quantity = int(input(" SELECT QUANTITY : "))
    
    if quantity == 0:
        print(" PLEASE SELECT QUANTITY")
    elif quantity == 1:
        print(" THANKS YOU FOR YOUR ORDER")
    elif quantity == 2:
        print(" THANKS YOU FOR YOUR ORDER")
    elif quantity == 3:
        print(" THANKS YOU FOR YOUR ORDER")
    elif quantity == 4:
        print(" THANKS YOU FOR YOUR ORDER")
    elif quantity == 5:
        print(" THANKS YOU FOR YOUR ORDER")
    else:
        print(" NOT POSSIBLE")
    
elif menu == 2:
    for i in steaks:
        
        print(i)
        
    
    select = int(input(" SELECT STEAKS: "))
    
    if select == 1:
        print(steaks[1])
    elif select == 2:
        print(steaks[2])
    elif select == 3:
        print(steaks[3])
    elif select == 4:
        print(steaks[4])
       
    else:
        print("NOT POSSIBLE")
        
         
        
    quantity = int(input(" ENTER QUANTITY : "))
    
    if quantity == 0:
        print(" NOT POSSIBLE")
    elif quantity == 1:
        print(" THANKS FOR YOUR ORDER")
    elif quantity == 2:
        print(" THANKS FOR YOUR ORDER")
    elif quantity == 3:
        print(" THANKS YOU FOR YOUR ORDER")
    elif quantity == 4:
        print(" THANKS YOU FOR YOUR ORDER")
    elif quantity == 5:
        print(" THANKS YOU FOR YOUR ORDER")
        
    else:
        print("NOT POSSIBLE")
else:
    print("\nExit")
# Out:
#  [1] BURGERS [2] STEAKS [3] EXIT
#
#   SELECT ITEMS : 1
# ['Zinger Burger : 230/-']
# ['Zinger Cheese Burger : 260/-']
# ['Thames Special Burger : 320/-']
# ['Beef Burger : 250/-']
# ['Tower Burger : 320/-']
# ['Fish Burger : 260']
# ['Fish Cheese Burger : 290/-']
# ['Fire Stone Burger : 170/-']
# ['Crispy Burger : 170/-']
# ['Chicken Burger : 180/-']
# ['Tikka Burger : 170/-']
# ['Shami Burger : 170/-']
# SELECT BURGERS :2
# ['Thames Special Burger : 320/-']
#  SELECT QUANTITY : 2
#  THANKS YOU FOR YOUR ORDER

# %%
menu = int(input(' ORDER FROM THE THE ITEMS MENSIONED BELOW \n [1]. PIZZAS \n [2]. BURGERS \n [3]. STEAKS \n [4]. EXIT \n \n  PLZ ENTER THE ORDER NO THAT YOU WANT : '))

burgers = [['Zinger Burger : 230/-'],['Zinger Cheese Burger : 260/-'],['Thames Special Burger : 320/-'],['Beef Burger : 250/-'],['Tower Burger : 320/-'],['Fish Burger : 260'],['Fish Cheese Burger : 290/-'],['Fire Stone Burger : 170/-'],['Crispy Burger : 170/-'],['Chicken Burger : 180/-'],['Tikka Burger : 170/-'],['Shami Burger : 170/-']]
steaks = [['Arizona Steak(Char grilled beef or chicken topped with spicy American sauce) : 650/-'],['Mushroom Steak(Tender line char grilled beef or chicken topped with creamy mahroom sauce) : 650/-'],['Pepper Steak(Tender line beef or chickenmedallion grilled top with pepper corn sauce ) : 650/-'],['Polo Tuscany(Char grilled steak topped with chef special sauce and slice cheesy ) : 650/-']]

if menu == 1:
    for a in burgers:
        print(a)
        
    print("\n NOW SELECT THE BURGERS YOU WANT :")
    
    select = int(input("\n SELECT PIZZA PLZ :"))
    
    if select == 1:
        print("\n YOU SELECTED CHICKEN TIKKA WHICH WILL COST YOU $200")
    elif select == 2:
        print("\n YOU SELECTED CHICKEN FAJITA WHICH WILL COST YOU $250")
    elif select == 3:
        print("\n YOU SELECTED CHEESY PIZZA WHICH WILL COST YOU $320")
        
    else: 
        
        print("\n WRONG SELECTION")
        
        
    quantity = int(input("\n PLZ ENTER THE NUMBER OF PIZZAS YOU WANT : "))
    
    if quantity == 0:
        print("\n WE ARE SORRY THIS IS NOT POSSIBLE")
    elif quantity == 1:
        print("\n THANKS FOR ODERING SIR")
    elif quantity == 2:
        print("\n THANKS FOR ODERING SIR")
    else:
        print("\n SORRY SIR. WE ARE OUT OF STOCK. PLZ SELECT AGAIN")
    
    confirm =int(input("\n TO CONFIRM YOUR ORDER PLZ PRESS 1 : "))

    if confirm ==1:
        print("\n ORDER CONFIRMED")
    else:
        print("\n YOUR ORDER HAS BEEN CANCELED")
